# %% [markdown]
# The reason to drop the columns at the end TAX, CHAS came because of poor correlation and too many empty data fields. Using some of the techniques learned from class I came up with the decision to drop field which seem to not correlate with the data at all. Also, fields with many empty fields do not yield data to be used for correlation either.

# %%
import math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
houseData = pd.read_csv("boston_corrected.csv", keep_default_na=False, low_memory=False)

# %%
houseData.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %%
houseData.head(6)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2
# 5  394.12   5.21   28.7

# %%
plt.title('Boston Housing Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.plot(houseData['AGE'], houseData['CRIM'], color = "red", linewidth = 1.5, linestyle = "-.", label = "y_sin")
#plt.plot(x, y_cos, marker = '+', linestyle = '-', label = 'y_cos')
plt.legend(loc = "upper left")
plt.show()

# %%
plt.scatter(houseData["AGE"], houseData['PRICE'], s = 50, alpha = 0.8)
plt.colorbar()
plt.show()

# %%
plt.bar(houseData['TAX'], houseData['PRICE'])
# Out:
# <BarContainer object of 506 artists>

# %%
houseData.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT', 'PRICE']

#Step 8: Pearson Ranking
#set up the figure size
#%matplotlib inline
plt.rcParams['figure.figsize'] = (15, 7)

# import the package for visulization of the correlation
from yellowbrick.features import Rank2D

# extract the numpy arrays from the data frame
X = houseData[columns].to_numpy()

# instantiate the visualizer with the Covariance ranking algorithm
visualizer = Rank2D(features=columns, algorithm='pearson')
visualizer.fit(X)                # Fit the data to the visualizer
visualizer.transform(X)             # Tr
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 3.9690e+02, 4.9800e+00,
#         2.4000e+01],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 3.9690e+02, 9.1400e+00,
#         2.1600e+01],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 3.9283e+02, 4.0300e+00,
#         3.4700e+01],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 5.6400e+00,
#         2.3900e+01],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 3.9345e+02, 6.4800e+00,
#         2.2000e+01],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 7.8800e+00,
#         1.1900e+01]])

# %%
from sklearn.feature_selection import mutual_info_regression
from scipy import sparse

corr_matrix = houseData.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k = 1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

# according to the report 75% zeros, remove
houseData = houseData.drop(["ZN"], axis=1).drop(to_drop, axis=1).drop(["CHAS"], axis=1)
spareMatrix = sparse.dok_matrix(houseData.drop(["CRIM"], axis=1))

mutualInfoRequession = mutual_info_regression(spareMatrix, houseData["CRIM"])

# %%
to_drop
# Out:
# ['TAX']
